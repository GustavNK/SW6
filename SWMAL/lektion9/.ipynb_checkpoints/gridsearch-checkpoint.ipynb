# %% [markdown]
# # SWMAL Exercise
#
#
# ## Hyperparameters and Gridsearch
#
# When instantiating a Scikit-learn model in python most or all constructor parameters have _default_ values. These values are not part of the internal model and are hence called ___hyperparameters___---in contrast to _normal_ model parameters, for example the neuron weights, $\mathbf w$, for an `MLP` model.
#
# ### Manual Tuning Hyperparameters
#
# Below is an example of the python constructor for the support-vector classifier `sklearn.svm.SVC`, with say the `kernel` hyperparameter having the default value `'rbf'`. If you should choose, what would you set it to other than `'rbf'`?
#
# ```python
# class sklearn.svm.SVC(
#     C=1.0,
#     kernel=’rbf’,
#     degree=3,
#     gamma=’auto_deprecated’,
#     coef0=0.0,
#     shrinking=True,
#     probability=False,
#     tol=0.001,
#     cache_size=200,
#     class_weight=None,
#     verbose=False,
#     max_iter=-1,
#     decision_function_shape=’ovr’,
#     random_state=None
#   )
# ```
#
# The default values might be a sensible general starting point, but for your data, you might want to optimize the hyperparameters to yield a better result.
#
# To be able to set `kernel` to a sensible value you need to go into the documentation for the `SVC` and understand what the kernel parameter represents, and what values it can be set to, and you need to understand the consequences of setting `kernel` to something different than the default...and the story repeats for every other hyperparameter!
#
# ### Brute Force  Search
#
# An alternative to this structured, but time-consuming approach, is just to __brute-force__ a search of interesting hyperparameters, and  choose the 'best' parameters according to a fit-predict and some score, say 'f1'.
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L09/Figs/gridsearch.png"  alt="WARNING: could not get image from server."  style="width:350px">
# <small><em>
#     <center> Conceptual graphical view of grid search for two distinct hyperparameters. </center>
#     <center> Notice that you would normally search hyperparameters like `alpha` with an exponential range, say [0.01, 0.1, 1, 10] or similar.</center>
# </em></small>
#
# Now, you just pick out some hyperparameters, that you figure are important, set them to a suitable range, say
#
# ```python
#     'kernel':('linear', 'rbf'),
#     'C':[1, 10]
# ```
# and fire up a full (grid) search on this hyperparameter set, that will try out all your specified combination of `kernel` and `C` for the model, and then prints the hyperparameter set with the highest score...
#
# The demo code below sets up some of our well known 'hello-world' data and then run a _grid search_ on a particular model, here a _support-vector classifier_ (SVC)
#
# Other models and datasets  ('mnist', 'iris', 'moon') can also be examined.
#
# ### Qa Explain GridSearchCV
#
# There are two code cells below: 1) function setup, 2) the actual grid-search.
#
# Review the code cells and write a __short__ summary. Mainly focus on __cell 2__, but dig into cell 1 if you find it interesting (notice the use of local-function, a nifty feature in python).
#
# In detail, examine the lines:
#
# ```python
# grid_tuned = GridSearchCV(model, tuning_parameters, ..
# grid_tuned.fit(X_train, y_train)
# ..
# FullReport(grid_tuned , X_test, y_test, time_gridsearch)
# ```
# and write a short description of how the `GridSeachCV` works: explain how the search parameter set is created and the overall search mechanism is functioning (without going into too much detail).
#
# What role does the parameter `scoring='f1_micro'` play in the `GridSearchCV`, and what does `n_jobs=-1` mean?

# %%
# TODO: Qa, code review..cell 1) function setup

from time import time
import numpy as np

from sklearn import svm
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn import datasets

from libitmal import dataloaders as itmaldataloaders # Needed for load of iris, moon and mnist

currmode="N/A" # GLOBAL var!

def SearchReport(model): 
    
    def GetBestModelCTOR(model, best_params):
        def GetParams(best_params):
            ret_str=""          
            for key in sorted(best_params):
                value = best_params[key]
                temp_str = "'" if str(type(value))=="<class 'str'>" else ""
                if len(ret_str)>0:
                    ret_str += ','
                ret_str += f'{key}={temp_str}{value}{temp_str}'  
            return ret_str          
        try:
            param_str = GetParams(best_params)
            return type(model).__name__ + '(' + param_str + ')' 
        except:
            return "N/A(1)"
        
    print("\nBest model set found on train set:")
    print()
    print(f"\tbest parameters={model.best_params_}")
    print(f"\tbest '{model.scoring}' score={model.best_score_}")
    print(f"\tbest index={model.best_index_}")
    print()
    print(f"Best estimator CTOR:")
    print(f"\t{model.best_estimator_}")
    print()
    try:
        print(f"Grid scores ('{model.scoring}') on development set:")
        means = model.cv_results_['mean_test_score']
        stds  = model.cv_results_['std_test_score']
        i=0
        for mean, std, params in zip(means, stds, model.cv_results_['params']):
            print("\t[%2d]: %0.3f (+/-%0.03f) for %r" % (i, mean, std * 2, params))
            i += 1
    except:
        print("WARNING: the random search do not provide means/stds")
    
    global currmode                
    assert "f1_micro"==str(model.scoring), f"come on, we need to fix the scoring to be able to compare model-fits! Your scoreing={str(model.scoring)}...remember to add scoring='f1_micro' to the search"   
    return f"best: dat={currmode}, score={model.best_score_:0.5f}, model={GetBestModelCTOR(model.estimator,model.best_params_)}", model.best_estimator_ 

def ClassificationReport(model, X_test, y_test, target_names=None):
    assert X_test.shape[0]==y_test.shape[0]
    print("\nDetailed classification report:")
    print("\tThe model is trained on the full development set.")
    print("\tThe scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, model.predict(X_test)                 
    print(classification_report(y_true, y_pred, target_names))
    print()
    
def FullReport(model, X_test, y_test, t):
    print(f"SEARCH TIME: {t:0.2f} sec")
    beststr, bestmodel = SearchReport(model)
    ClassificationReport(model, X_test, y_test)    
    print(f"CTOR for best model: {bestmodel}\n")
    print(f"{beststr}\n")
    return beststr, bestmodel
    
def LoadAndSetupData(mode, test_size=0.3):
    assert test_size>=0.0 and test_size<=1.0
    
    def ShapeToString(Z):
        n = Z.ndim
        s = "("
        for i in range(n):
            s += f"{Z.shape[i]:5d}"
            if i+1!=n:
                s += ";"
        return s+")"

    global currmode
    currmode=mode
    print(f"DATA: {currmode}..")
    
    if mode=='moon':
        X, y = itmaldataloaders.MOON_GetDataSet(n_samples=5000, noise=0.2)
        itmaldataloaders.MOON_Plot(X, y)
    elif mode=='mnist':
        X, y = itmaldataloaders.MNIST_GetDataSet(load_mode=0)
        if X.ndim==3:
            X=np.reshape(X, (X.shape[0], -1))
    elif mode=='iris':
        X, y = itmaldataloaders.IRIS_GetDataSet()
    else:
        raise ValueError(f"could not load data for that particular mode='{mode}', only 'moon'/'mnist'/'iris' supported")
        
    print(f'  org. data:  X.shape      ={ShapeToString(X)}, y.shape      ={ShapeToString(y)}')

    assert X.ndim==2
    assert X.shape[0]==y.shape[0]
    assert y.ndim==1 or (y.ndim==2 and y.shape[1]==0)    
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=0, shuffle=True
    )
    
    print(f'  train data: X_train.shape={ShapeToString(X_train)}, y_train.shape={ShapeToString(y_train)}')
    print(f'  test data:  X_test.shape ={ShapeToString(X_test)}, y_test.shape ={ShapeToString(y_test)}')
    print()
    
    return X_train, X_test, y_train, y_test

print('OK(function setup, hope MNIST loads works, seem best if you got Keras or Tensorflow installed!)')
# Out:
# OK(function setup, hope MNIST loads works, seem best if you got Keras or Tensorflow installed!)

# %%
# TODO: Qa, code review..cell 2) the actual grid-search

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'iris')  # 'iris', 'moon', or 'mnist'

# Setup search parameters
model = svm.SVC(
    gamma=0.001
)  # NOTE: gamma="scale" does not work in older Scikit-learn frameworks,
# FIX:  replace with model = svm.SVC(gamma=0.001)

tuning_parameters = {
    'kernel': ('linear', 'rbf'), 
    'C': [0.1, 1, 10]
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model,
                          tuning_parameters,
                          cv=CV,
                          scoring='f1_micro',
                          verbose=VERBOSE,
                          n_jobs=-1)
grid_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(grid_tuned, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
#
# SEARCH TIME: 0.04 sec
#
# Best model set found on train set:
#
# 	best parameters={'C': 1, 'kernel': 'linear'}
# 	best 'f1_micro' score=0.9714285714285715
# 	best index=2
#
# Best estimator CTOR:
# 	SVC(C=1, gamma=0.001, kernel='linear')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.962 (+/-0.093) for {'C': 0.1, 'kernel': 'linear'}
# 	[ 1]: 0.371 (+/-0.038) for {'C': 0.1, 'kernel': 'rbf'}
# 	[ 2]: 0.971 (+/-0.047) for {'C': 1, 'kernel': 'linear'}
# 	[ 3]: 0.695 (+/-0.047) for {'C': 1, 'kernel': 'rbf'}
# 	[ 4]: 0.952 (+/-0.085) for {'C': 10, 'kernel': 'linear'}
# 	[ 5]: 0.924 (+/-0.097) for {'C': 10, 'kernel': 'rbf'}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# CTOR for best model: SVC(C=1, gamma=0.001, kernel='linear')
#
# best: dat=iris, score=0.97143, model=SVC(C=1,kernel='linear')
#
# OK(grid-search)
# C:\Users\1chri\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass labels=None as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %% [markdown]
# ### Qb Hyperparameter Grid Search using an SDG classifier
#
# Now, replace the `svm.SVC` model with an `SGDClassifier` and a suitable set of the hyperparameters for that model.
#
# You need at least four or five different hyperparameters from the `SGDClassifier` in the search-space before it begins to take considerable compute time doing the full grid search.
#
# So, repeat the search with the `SGDClassifier`, and be sure to add enough hyperparameters to the grid-search, such that the search takes a considerable time to run, that is a couple of minutes or up to some hours..

# %%
from sklearn.linear_model import SGDClassifier

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'iris')  # 'iris', 'moon', or 'mnist'

# Setup search parameters
model = SGDClassifier()  # NOTE: gamma="scale" does not work in older Scikit-learn frameworks,

tuning_parameters = {
    'loss': ('log', 'epsilon_insensitive', 'huber'),
    'penalty': ('l2', 'l1', 'elasticnet'),
    'learning_rate': ('constant', 'optimal'),
    'early_stopping': (False, True),
    'eta0': (1.0, 2.0, 0.1)
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model,
                          tuning_parameters,
                          cv=CV,
                          scoring='f1_micro',
                          verbose=VERBOSE,
                          n_jobs=-1)
grid_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(grid_tuned, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
#
# SEARCH TIME: 5.07 sec
#
# Best model set found on train set:
#
# 	best parameters={'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'elasticnet'}
# 	best 'f1_micro' score=0.8952380952380953
# 	best index=38
#
# Best estimator CTOR:
# 	SGDClassifier(eta0=0.1, learning_rate='constant', loss='log',
#               penalty='elasticnet')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.676 (+/-0.423) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l2'}
# 	[ 1]: 0.819 (+/-0.304) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l1'}
# 	[ 2]: 0.790 (+/-0.230) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[ 3]: 0.333 (+/-0.426) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[ 4]: 0.324 (+/-0.071) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[ 5]: 0.286 (+/-0.289) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[ 6]: 0.305 (+/-0.230) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l2'}
# 	[ 7]: 0.457 (+/-0.230) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1'}
# 	[ 8]: 0.314 (+/-0.076) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[ 9]: 0.705 (+/-0.071) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}
# 	[10]: 0.714 (+/-0.217) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}
# 	[11]: 0.648 (+/-0.384) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[12]: 0.400 (+/-0.286) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[13]: 0.381 (+/-0.159) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[14]: 0.324 (+/-0.164) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[15]: 0.495 (+/-0.517) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2'}
# 	[16]: 0.429 (+/-0.159) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l1'}
# 	[17]: 0.352 (+/-0.097) for {'early_stopping': False, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[18]: 0.752 (+/-0.495) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l2'}
# 	[19]: 0.667 (+/-0.085) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l1'}
# 	[20]: 0.581 (+/-0.220) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[21]: 0.305 (+/-0.047) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[22]: 0.333 (+/-0.060) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[23]: 0.314 (+/-0.393) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[24]: 0.467 (+/-0.338) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l2'}
# 	[25]: 0.362 (+/-0.305) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1'}
# 	[26]: 0.343 (+/-0.071) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[27]: 0.810 (+/-0.361) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}
# 	[28]: 0.771 (+/-0.265) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}
# 	[29]: 0.743 (+/-0.155) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[30]: 0.410 (+/-0.273) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[31]: 0.352 (+/-0.369) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[32]: 0.352 (+/-0.047) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[33]: 0.438 (+/-0.229) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2'}
# 	[34]: 0.352 (+/-0.076) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l1'}
# 	[35]: 0.314 (+/-0.047) for {'early_stopping': False, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[36]: 0.800 (+/-0.229) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l2'}
# 	[37]: 0.829 (+/-0.214) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l1'}
# 	[38]: 0.895 (+/-0.140) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[39]: 0.333 (+/-0.060) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[40]: 0.429 (+/-0.341) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[41]: 0.362 (+/-0.214) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[42]: 0.752 (+/-0.093) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l2'}
# 	[43]: 0.629 (+/-0.164) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1'}
# 	[44]: 0.762 (+/-0.170) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[45]: 0.752 (+/-0.279) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}
# 	[46]: 0.867 (+/-0.203) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}
# 	[47]: 0.771 (+/-0.383) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[48]: 0.286 (+/-0.295) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[49]: 0.381 (+/-0.289) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[50]: 0.333 (+/-0.276) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[51]: 0.410 (+/-0.214) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2'}
# 	[52]: 0.381 (+/-0.248) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l1'}
# 	[53]: 0.429 (+/-0.289) for {'early_stopping': False, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[54]: 0.781 (+/-0.214) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l2'}
# 	[55]: 0.724 (+/-0.456) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l1'}
# 	[56]: 0.657 (+/-0.194) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[57]: 0.276 (+/-0.285) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[58]: 0.362 (+/-0.047) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[59]: 0.362 (+/-0.114) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[60]: 0.476 (+/-0.351) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l2'}
# 	[61]: 0.400 (+/-0.286) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1'}
# 	[62]: 0.467 (+/-0.368) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[63]: 0.676 (+/-0.071) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}
# 	[64]: 0.819 (+/-0.298) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}
# 	[65]: 0.743 (+/-0.114) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[66]: 0.267 (+/-0.267) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[67]: 0.352 (+/-0.047) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[68]: 0.305 (+/-0.187) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[69]: 0.333 (+/-0.060) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2'}
# 	[70]: 0.305 (+/-0.260) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l1'}
# 	[71]: 0.429 (+/-0.289) for {'early_stopping': True, 'eta0': 1.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[72]: 0.686 (+/-0.339) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l2'}
# 	[73]: 0.686 (+/-0.076) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l1'}
# 	[74]: 0.667 (+/-0.148) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[75]: 0.343 (+/-0.071) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[76]: 0.276 (+/-0.279) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[77]: 0.229 (+/-0.338) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[78]: 0.371 (+/-0.071) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l2'}
# 	[79]: 0.410 (+/-0.311) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1'}
# 	[80]: 0.390 (+/-0.236) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[81]: 0.743 (+/-0.453) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}
# 	[82]: 0.590 (+/-0.267) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}
# 	[83]: 0.581 (+/-0.472) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[84]: 0.333 (+/-0.060) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[85]: 0.352 (+/-0.076) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[86]: 0.257 (+/-0.267) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[87]: 0.410 (+/-0.166) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2'}
# 	[88]: 0.295 (+/-0.140) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l1'}
# 	[89]: 0.352 (+/-0.097) for {'early_stopping': True, 'eta0': 2.0, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[90]: 0.714 (+/-0.085) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l2'}
# 	[91]: 0.819 (+/-0.272) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'l1'}
# 	[92]: 0.781 (+/-0.214) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[93]: 0.476 (+/-0.319) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[94]: 0.410 (+/-0.311) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[95]: 0.333 (+/-0.085) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[96]: 0.695 (+/-0.129) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l2'}
# 	[97]: 0.733 (+/-0.097) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1'}
# 	[98]: 0.752 (+/-0.203) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'elasticnet'}
# 	[99]: 0.714 (+/-0.376) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}
# 	[100]: 0.648 (+/-0.374) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}
# 	[101]: 0.695 (+/-0.393) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'elasticnet'}
# 	[102]: 0.343 (+/-0.071) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2'}
# 	[103]: 0.324 (+/-0.071) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l1'}
# 	[104]: 0.343 (+/-0.456) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet'}
# 	[105]: 0.343 (+/-0.071) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2'}
# 	[106]: 0.371 (+/-0.071) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l1'}
# 	[107]: 0.343 (+/-0.071) for {'early_stopping': True, 'eta0': 0.1, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet'}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.33      0.50        18
#            2       0.48      1.00      0.65        11
#
#     accuracy                           0.73        45
#    macro avg       0.83      0.78      0.72        45
# weighted avg       0.87      0.73      0.71        45
#
#
# CTOR for best model: SGDClassifier(eta0=0.1, learning_rate='constant', loss='log',
#               penalty='elasticnet')
#
# best: dat=iris, score=0.89524, model=SGDClassifier(early_stopping=False,eta0=0.1,learning_rate='constant',loss='log',penalty='elasticnet')
#
# OK(grid-search)
# C:\Users\1chri\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass labels=None as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %% [markdown]
# ### Qc Hyperparameter Random  Search using an SDG classifier
#
# Now, add code to run a `RandomizedSearchCV` instead.
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L09/Figs/randomsearch.png" alt="WARNING: could not get image from server."  style="width:350px" >
# <small><em>
#     <center> Conceptual graphical view of randomized search for two distinct hyperparameters. </center>
# </em></small>
#
# Use these default parameters for the random search, similar to the default parameters for the grid search
#
# ```python
# random_tuned = RandomizedSearchCV(
#     model,
#     tuning_parameters,
#     n_iter=20,
#     random_state=42,
#     cv=CV,
#     scoring='f1_micro',
#     verbose=VERBOSE,
#     n_jobs=-1
# )
# ```
#
# but with the two new parameters, `n_iter` and `random_state` added. Since the search-type is now random, the `random_state` gives sense, but essential to random search is the new `n_tier` parameter.
#
# So: investigate the `n_iter` parameter...in code and write a conceptual explanation  in text.
#
# Comparison of time (seconds) to complete `GridSearch` versus `RandomizedSearchCV`, does not necessarily give any sense, if your grid search completes in a few seconds (as for the iris tiny-data). You need a search that runs for minutes, hours, or days.
#
# But you could compare the best-tuned parameter set and best scoring for the two methods. Is the random search best model close to the grid search?

# %%
from sklearn.linear_model import SGDClassifier

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'iris')  # 'iris', 'moon', or 'mnist'

# Setup search parameters
model = SGDClassifier()  # NOTE: gamma="scale" does not work in older Scikit-learn frameworks,

tuning_parameters = {
    'loss': ('log', 'epsilon_insensitive', 'huber'),
    'penalty': ('l2', 'l1', 'elasticnet'),
    'learning_rate': ('constant', 'optimal'),
    'early_stopping': (False, True),
    'eta0': (1.0, 2.0, 0.1)
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
start = time()
random_tuned = RandomizedSearchCV(
    model, 
    tuning_parameters, 
    n_iter=20, 
    random_state=42, 
    cv=CV, 
    scoring='f1_micro', 
    verbose=VERBOSE, 
    n_jobs=-1)
random_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(random_tuned, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
#
# SEARCH TIME: 4.08 sec
#
# Best model set found on train set:
#
# 	best parameters={'penalty': 'l1', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': False}
# 	best 'f1_micro' score=0.8857142857142858
# 	best index=1
#
# Best estimator CTOR:
# 	SGDClassifier(eta0=1.0, loss='log', penalty='l1')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.238 (+/-0.248) for {'penalty': 'elasticnet', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[ 1]: 0.886 (+/-0.214) for {'penalty': 'l1', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': False}
# 	[ 2]: 0.362 (+/-0.076) for {'penalty': 'l1', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': False}
# 	[ 3]: 0.676 (+/-0.378) for {'penalty': 'elasticnet', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 2.0, 'early_stopping': True}
# 	[ 4]: 0.457 (+/-0.384) for {'penalty': 'elasticnet', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': True}
# 	[ 5]: 0.267 (+/-0.230) for {'penalty': 'l1', 'loss': 'epsilon_insensitive', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': True}
# 	[ 6]: 0.229 (+/-0.258) for {'penalty': 'l2', 'loss': 'epsilon_insensitive', 'learning_rate': 'optimal', 'eta0': 2.0, 'early_stopping': False}
# 	[ 7]: 0.762 (+/-0.241) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 0.1, 'early_stopping': False}
# 	[ 8]: 0.352 (+/-0.076) for {'penalty': 'elasticnet', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 0.1, 'early_stopping': True}
# 	[ 9]: 0.743 (+/-0.214) for {'penalty': 'elasticnet', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': False}
# 	[10]: 0.619 (+/-0.356) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 2.0, 'early_stopping': True}
# 	[11]: 0.410 (+/-0.273) for {'penalty': 'l1', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[12]: 0.714 (+/-0.120) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': False}
# 	[13]: 0.324 (+/-0.038) for {'penalty': 'elasticnet', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[14]: 0.686 (+/-0.047) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': False}
# 	[15]: 0.410 (+/-0.311) for {'penalty': 'l2', 'loss': 'huber', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': True}
# 	[16]: 0.695 (+/-0.305) for {'penalty': 'elasticnet', 'loss': 'log', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': True}
# 	[17]: 0.276 (+/-0.152) for {'penalty': 'l1', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[18]: 0.343 (+/-0.071) for {'penalty': 'l1', 'loss': 'huber', 'learning_rate': 'optimal', 'eta0': 0.1, 'early_stopping': True}
# 	[19]: 0.667 (+/-0.085) for {'penalty': 'l2', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 0.1, 'early_stopping': False}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        16
#            1       1.00      0.28      0.43        18
#            2       0.48      1.00      0.65        11
#
#     accuracy                           0.71        45
#    macro avg       0.81      0.76      0.68        45
# weighted avg       0.85      0.71      0.68        45
#
#
# CTOR for best model: SGDClassifier(eta0=1.0, loss='log', penalty='l1')
#
# best: dat=iris, score=0.88571, model=SGDClassifier(early_stopping=False,eta0=1.0,learning_rate='optimal',loss='log',penalty='l1')
#
# OK(grid-search)
# C:\Users\1chri\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass labels=None as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %% [markdown]
# ## Qd MNIST Search Quest II
#
# Finally, a search-quest competition: __who can find the best model+hyperparameters for the MNIST dataset?__
#
# You change to the MNIST data by calling `LoadAndSetupData('mnist')`, and this is a completely other ball-game that the iris _tiny-data_: it's much larger (but still far from _big-data_)!
#
# * You might opt for the exhaustive grid search, or use the faster but-less optimal random search...your choice.
#
# * You are free to pick any classifier in Scikit-learn, even algorithms we have not discussed yet---__except Neural Networks and KNeighborsClassifier!__.
#
# * Keep the score function at `f1_micro`, otherwise, we will be comparing 'æbler og pærer'.
#
# * And, you may also want to scale your input data for some models to perform better.
#
# * __REMEMBER__, DO NOT USE any Neural Network models. This also means not to use any `Keras` or `Tensorflow` models...since they outperform most other models, and there are also too many examples on the internet to cut-and-paste from!
#
# Check your result by printing the first _return_ value from `FullReport()`
# ```python
# b1, m1 = FullReport(random_tuned , X_test, y_test, time_randomsearch)
# print(b1)
# ```
# that will display a result like
# ```
# best: dat=mnist, score=0.90780, model=SGDClassifier(alpha=1.0,eta0=0.0001,learning_rate='invscaling')
# ```
# and paste your currently best model into the message box, for ITMAL group 09 like
# ```
# Grp09: best: dat=mnist, score=0.90780, model=SGDClassifier(alpha=1.0,eta0=0.0001,learning_rate='invscaling')
#
# Grp09: CTOR for best model: SGDClassifier(alpha=1.0, average=False, class_weight=None, early_stopping=False,
#               epsilon=0.1, eta0=0.0001, fit_intercept=True, l1_ratio=0.15,
#               learning_rate='invscaling', loss='hinge', max_iter=1000,
#               n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#               random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)
# ```
#
# on Brightspace: "L10: Regularisering, optimering og søgning" | "Qd MNIST Search Quest II"
#
# >  https://brightspace.au.dk/d2l/le/lessons/53939/topics/791969
#
# and, check if your score (for MNIST) is better than the currently best score. Republish if you get a better score than your own previously best.
#
# Remember to provide an ITMAL group name manually, so we can identify a winner: the 1. st price is  cake!
#
# For the journal hand-in, report your progress in scoring choosing different models, hyperparameters to search and how you might need to preprocess your data...and note, that the journal will not be accepted unless it contains information about Your results published on the Brightspace 'Search Quest II' page!

# %%
from sklearn.linear_model import SGDClassifier

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData('mnist')

# Setup search parameters
model = SGDClassifier()  # NOTE: gamma="scale" does not work in older Scikit-learn frameworks,

tuning_parameters = {
    'loss': ('log', 'epsilon_insensitive', 'huber'),
    'penalty': ('l2', 'l1', 'elasticnet'),
    'learning_rate': ('constant', 'optimal'),
    'early_stopping': (False, True),
    'eta0': (1.0, 2.0, 0.1)
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
start = time()
random_tuned = RandomizedSearchCV(
    model, 
    tuning_parameters, 
    n_iter=20, 
    random_state=42, 
    cv=CV, 
    scoring='f1_micro', 
    verbose=VERBOSE, 
    n_jobs=-1)
random_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(random_tuned, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# DATA: mnist..
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# 11501568/11490434 [==============================] - 1s 0us/step
#   org. data:  X.shape      =(70000;  784), y.shape      =(70000)
#   train data: X_train.shape=(49000;  784), y_train.shape=(49000)
#   test data:  X_test.shape =(21000;  784), y_test.shape =(21000)
#
# SEARCH TIME: 67875.03 sec
#
# Best model set found on train set:
#
# 	best parameters={'penalty': 'elasticnet', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 2.0, 'early_stopping': True}
# 	best 'f1_micro' score=0.8804489795918368
# 	best index=3
#
# Best estimator CTOR:
# 	SGDClassifier(early_stopping=True, eta0=2.0, loss='log', penalty='elasticnet')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.103 (+/-0.065) for {'penalty': 'elasticnet', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[ 1]: 0.867 (+/-0.008) for {'penalty': 'l1', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': False}
# 	[ 2]: 0.089 (+/-0.038) for {'penalty': 'l1', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': False}
# 	[ 3]: 0.880 (+/-0.006) for {'penalty': 'elasticnet', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 2.0, 'early_stopping': True}
# 	[ 4]: 0.105 (+/-0.062) for {'penalty': 'elasticnet', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': True}
# 	[ 5]: 0.092 (+/-0.034) for {'penalty': 'l1', 'loss': 'epsilon_insensitive', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': True}
# 	[ 6]: 0.114 (+/-0.054) for {'penalty': 'l2', 'loss': 'epsilon_insensitive', 'learning_rate': 'optimal', 'eta0': 2.0, 'early_stopping': False}
# 	[ 7]: 0.873 (+/-0.009) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 0.1, 'early_stopping': False}
# 	[ 8]: 0.124 (+/-0.059) for {'penalty': 'elasticnet', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 0.1, 'early_stopping': True}
# 	[ 9]: 0.863 (+/-0.018) for {'penalty': 'elasticnet', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': False}
# 	[10]: 0.873 (+/-0.012) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'optimal', 'eta0': 2.0, 'early_stopping': True}
# 	[11]: 0.111 (+/-0.074) for {'penalty': 'l1', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[12]: 0.818 (+/-0.047) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': False}
# 	[13]: 0.077 (+/-0.046) for {'penalty': 'elasticnet', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[14]: 0.817 (+/-0.013) for {'penalty': 'l2', 'loss': 'log', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': False}
# 	[15]: 0.079 (+/-0.019) for {'penalty': 'l2', 'loss': 'huber', 'learning_rate': 'optimal', 'eta0': 1.0, 'early_stopping': True}
# 	[16]: 0.797 (+/-0.052) for {'penalty': 'elasticnet', 'loss': 'log', 'learning_rate': 'constant', 'eta0': 1.0, 'early_stopping': True}
# 	[17]: 0.099 (+/-0.026) for {'penalty': 'l1', 'loss': 'epsilon_insensitive', 'learning_rate': 'constant', 'eta0': 2.0, 'early_stopping': True}
# 	[18]: 0.105 (+/-0.022) for {'penalty': 'l1', 'loss': 'huber', 'learning_rate': 'optimal', 'eta0': 0.1, 'early_stopping': True}
# 	[19]: 0.084 (+/-0.041) for {'penalty': 'l2', 'loss': 'huber', 'learning_rate': 'constant', 'eta0': 0.1, 'early_stopping': False}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      2077
#            1       0.94      0.97      0.96      2385
#            2       0.86      0.89      0.87      2115
#            3       0.87      0.85      0.86      2117
#            4       0.77      0.95      0.85      2004
#            5       0.85      0.80      0.82      1900
#            6       0.93      0.92      0.93      2045
#            7       0.86      0.93      0.89      2189
#            8       0.81      0.83      0.82      2042
#            9       0.93      0.61      0.74      2126
#
#     accuracy                           0.87     21000
#    macro avg       0.88      0.87      0.87     21000
# weighted avg       0.88      0.87      0.87     21000
#
#
# CTOR for best model: SGDClassifier(early_stopping=True, eta0=2.0, loss='log', penalty='elasticnet')
#
# best: dat=mnist, score=0.88045, model=SGDClassifier(early_stopping=True,eta0=2.0,learning_rate='optimal',loss='log',penalty='elasticnet')
#
# OK(grid-search)
# C:\Users\1chri\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass labels=None as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %% [markdown]
# REVISIONS||
# ---------||
# 2018-03-01| CEF, initial.
# 2018-03-05| CEF, updated.
# 2018-03-06| CEF, updated and spell checked.
# 2018-03-06| CEF, major overhaul of functions.
# 2018-03-06| CEF, fixed problem with MNIST load and Keras.
# 2018-03-07| CEF, modified report functions and changed Qc+d.
# 2018-03-11| CEF, updated Qd.
# 2018-03-12| CEF, added grid and random search figs and added bullets to Qd.
# 2018-03-13| CEF, fixed SVC and gamma issue, and changed dataload to be in fetchmode (non-keras).
# 2019-10-15| CEF, updated for ITMAL E19
# 2019-10-19| CEF, minor text update.
# 2019-10-23| CEF, changed demo model i Qd) from MLPClassifier to SVC.
# 2020-03-14| CEF, updated to ITMAL F20.
# 2020-10-20| CEF, updated to ITMAL E20.
# 2020-10-27| CEF, type fixes and minor update.
# 2020-10-28| CEF, added extra journal hand-in specs for Search Quest II, Qd.
# 2020-10-30| CEF, added non-use of KNeighborsClassifier to Search Quest II, Qd.
# 2020-11-19| CEF, changed load_mode=2 (Keras) to load_mode=0 (auto) for MNIST loader.
# 2021-03-17| CEF, updated to ITMAL F21.
# 2021-10-31| CEF, updated to ITMAL E21.
# 2021-11-05| CEF, removed iid=True paramter from GridSearchCV(), not present in current version of Scikit-learn (0.24.1).
# 2022-03-31| CEF, updated to SWMAL F22.
